# %%
#ladowanie biblioteki Pandas
import pandas as pd
#zaimportuj modul pyplot z biblioteki matplotlib
import matplotlib.pyplot as plt

# %%
#tworzenie ramki danych ze slownika

data = {'col_1': [3, 2, 1, 0], 'col_2': ['a', 'b', 'c', 'd']}

pd.DataFrame.from_dict(data)
# Out:
#    col_1 col_2
# 0      3     a
# 1      2     b
# 2      1     c
# 3      0     d

# %%
#zachowanie ramki danych pobranych z pliku w formacie csv (xlsx)

df = pd.read_csv('IHME_GBD_2019_CHEWING_TOB_1990_2019_DATA_Y2021M05D27.CSV', encoding='latin1')
print(df.head())
# Out:
#    measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0           5   Prevalence            1        Global       1     Male
# 1           5   Prevalence            1        Global       2   Female
# 2           5   Prevalence            1        Global       1     Male
# 3           5   Prevalence            1        Global       2   Female
# 4           5   Prevalence            1        Global       1     Male
#
#    age_group_id age_group_name  rei_id         rei_name  metric_id  \
# 0             8       15 to 19     332  Chewing tobacco          3
# 1             8       15 to 19     332  Chewing tobacco          3
# 2             8       15 to 19     332  Chewing tobacco          3
# 3             8       15 to 19     332  Chewing tobacco          3
# 4             8       15 to 19     332  Chewing tobacco          3
#
#   metric_name  year_id       val     upper     lower
# 0        Rate     1990  0.038740  0.055586  0.027147
# ...

# %%
#tworzenie ramki danych z listy list

lists_income = [["Adam", "Kuba", "Robert"], 
[4500,   5500,  6500]]

pd.DataFrame(lists_income)
# Out:
#       0     1       2
# 0  Adam  Kuba  Robert
# 1  4500  5500    6500

# %%
#transponowanie (wymieniamy kolumny a wierszy)

df1 = pd.DataFrame.transpose(pd.DataFrame(lists_income))
print(df1)
# Out:
#         0     1
# 0    Adam  4500
# 1    Kuba  5500
# 2  Robert  6500

# %%
#wy´swietli´c pierwsze 10 wierszy ramki danych

df.head(10)
# Out:
#    measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0           5   Prevalence            1        Global       1     Male
# 1           5   Prevalence            1        Global       2   Female
# 2           5   Prevalence            1        Global       1     Male
# 3           5   Prevalence            1        Global       2   Female
# 4           5   Prevalence            1        Global       1     Male
# 5           5   Prevalence            1        Global       2   Female
# 6           5   Prevalence            1        Global       1     Male
# 7           5   Prevalence            1        Global       2   Female
# 8           5   Prevalence            1        Global       1     Male
# 9           5   Prevalence            1        Global       2   Female
#
#    age_group_id age_group_name  rei_id         rei_name  metric_id  \
# 0             8       15 to 19     332  Chewing tobacco          3
# ...

# %%
#wy´swietli´c ostatnie 10 wierszy ramki danych

df.tail(10)
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 350540           5   Prevalence          522         Sudan       3     Both
# 350541           5   Prevalence          522         Sudan       3     Both
# 350542           5   Prevalence          522         Sudan       3     Both
# 350543           5   Prevalence          522         Sudan       3     Both
# 350544           5   Prevalence          522         Sudan       3     Both
# 350545           5   Prevalence          522         Sudan       3     Both
# 350546           5   Prevalence          522         Sudan       3     Both
# 350547           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
# 350549           5   Prevalence          522         Sudan       3     Both
#
#         age_group_id    age_group_name  rei_id         rei_name  metric_id  \
# ...

# %%
#wy´swietli´c informacje˛ o ramce danych

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350550 entries, 0 to 350549
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   measure_id      350550 non-null  int64
#  1   measure_name    350550 non-null  object
#  2   location_id     350550 non-null  int64
#  3   location_name   350550 non-null  object
#  4   sex_id          350550 non-null  int64
#  5   sex_name        350550 non-null  object
#  6   age_group_id    350550 non-null  int64
#  7   age_group_name  350550 non-null  object
#  8   rei_id          350550 non-null  int64
#  9   rei_name        350550 non-null  object
#  10  metric_id       350550 non-null  int64
#  11  metric_name     350550 non-null  object
#  12  year_id         350550 non-null  int64
#  13  val             350550 non-null  float64
#  14  upper           350550 non-null  float64
#  15  lower           350550 non-null  float64
# dtypes: float64(3), int64(7), object(6)
# ...

# %%
#wy´swietli´c, ile wierszy i kolumn znajduje sie˛ w ramce danych

df.shape
# Out:
# (350550, 16)

# %%
#wy´swietli´c informacje˛ statystyczna˛ o kolumnach liczbowych (warto´sci
#niepowtarzalne, ´srednia, odchylenie standardowe, minimum, kwartyle,
#maksimum)

df.describe()
# Out:
#        measure_id    location_id         sex_id   age_group_id    rei_id  \
# count    350550.0  350550.000000  350550.000000  350550.000000  350550.0
# mean          5.0     135.639024       2.000000      29.421053     332.0
# std           0.0      98.136414       0.816498      48.993427       0.0
# min           5.0       1.000000       1.000000       8.000000     332.0
# 25%           5.0      62.000000       1.000000      12.000000     332.0
# 50%           5.0     122.000000       2.000000      17.000000     332.0
# 75%           5.0     182.000000       3.000000      27.000000     332.0
# max           5.0     522.000000       3.000000     235.000000     332.0
#
#        metric_id        year_id            val          upper          lower
# count   350550.0  350550.000000  350550.000000  350550.000000  350550.000000
# mean         3.0    2004.500000       0.020179       0.032878       0.011704
# std          0.0       8.655454       0.049594       0.070631       0.034127
# ...

# %%
#wy´swietli´c informacje˛ statystyczna˛ o kolumnach kategoryzowanych (ile
#unikalnych warto´sci, top - jaka jest najpopularniejsza warto´s´c, freq -
#jak cze˛sto najpopularniejsza


df.describe(include = 'all')
# Out:
#         measure_id measure_name    location_id location_name         sex_id  \
# count     350550.0       350550  350550.000000        350550  350550.000000
# unique         NaN            1            NaN           205            NaN
# top            NaN   Prevalence            NaN        Global            NaN
# freq           NaN       350550            NaN          1710            NaN
# mean           5.0          NaN     135.639024           NaN       2.000000
# std            0.0          NaN      98.136414           NaN       0.816498
# min            5.0          NaN       1.000000           NaN       1.000000
# 25%            5.0          NaN      62.000000           NaN       1.000000
# 50%            5.0          NaN     122.000000           NaN       2.000000
# 75%            5.0          NaN     182.000000           NaN       3.000000
# max            5.0          NaN     522.000000           NaN       3.000000
#
# ...

# %%
#usuna˛´c brakuja˛ce warto´sci w ramce danych

df.dropna(inplace=True)
print(df)
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0                5   Prevalence            1        Global       1     Male
# 1                5   Prevalence            1        Global       2   Female
# 2                5   Prevalence            1        Global       1     Male
# 3                5   Prevalence            1        Global       2   Female
# 4                5   Prevalence            1        Global       1     Male
# ...            ...          ...          ...           ...     ...      ...
# 350545           5   Prevalence          522         Sudan       3     Both
# 350546           5   Prevalence          522         Sudan       3     Both
# 350547           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
# 350549           5   Prevalence          522         Sudan       3     Both
#
# ...

# %%
#przedstawi´c wyb´or wierszy i kolumny u˙zywaja˛c nazw oraz indeks´ow na
#r´o˙zne sposoby

df["measure_name"] # zmienic nazwe po swoj zbior
# Out:
# 0         Prevalence
# 1         Prevalence
# 2         Prevalence
# 3         Prevalence
# 4         Prevalence
#              ...
# 350545    Prevalence
# 350546    Prevalence
# 350547    Prevalence
# 350548    Prevalence
# 350549    Prevalence
# Name: measure_name, Length: 350550, dtype: object

# %%
df.measure_name # zmienic nazwe pod swoj zbior
# Out:
# 0         Prevalence
# 1         Prevalence
# 2         Prevalence
# 3         Prevalence
# 4         Prevalence
#              ...
# 350545    Prevalence
# 350546    Prevalence
# 350547    Prevalence
# 350548    Prevalence
# 350549    Prevalence
# Name: measure_name, Length: 350550, dtype: object

# %%
df[["measure_name","age_group_name","year_id"]] # wybór kilku kolumn jednocześnie zmienic pod swoj zbior
# Out:
#        measure_name    age_group_name  year_id
# 0        Prevalence          15 to 19     1990
# 1        Prevalence          15 to 19     1990
# 2        Prevalence          15 to 19     1991
# 3        Prevalence          15 to 19     1991
# 4        Prevalence          15 to 19     1992
# ...             ...               ...      ...
# 350545   Prevalence  Age standardized     2015
# 350546   Prevalence  Age standardized     2016
# 350547   Prevalence  Age standardized     2017
# 350548   Prevalence  Age standardized     2018
# 350549   Prevalence  Age standardized     2019
#
# [350550 rows x 3 columns]

# %%
df.loc[:, "location_name":"val"] # wybierz wszystkie wiersze i kolumny od „location” do „val” zmienic pod swoj zbior
# Out:
#        location_name  sex_id sex_name  age_group_id    age_group_name  rei_id  \
# 0             Global       1     Male             8          15 to 19     332
# 1             Global       2   Female             8          15 to 19     332
# 2             Global       1     Male             8          15 to 19     332
# 3             Global       2   Female             8          15 to 19     332
# 4             Global       1     Male             8          15 to 19     332
# ...              ...     ...      ...           ...               ...     ...
# 350545         Sudan       3     Both            27  Age standardized     332
# 350546         Sudan       3     Both            27  Age standardized     332
# 350547         Sudan       3     Both            27  Age standardized     332
# 350548         Sudan       3     Both            27  Age standardized     332
# 350549         Sudan       3     Both            27  Age standardized     332
#
# ...

# %%
df.loc[100:110, "location_name":"val"] #wybierz wiersze od 100-110 i kolumny od locationa_name do val
# Out:
#     location_name  sex_id sex_name  age_group_id age_group_name  rei_id  \
# 100        Global       1     Male             9       20 to 24     332
# 101        Global       2   Female             9       20 to 24     332
# 102        Global       1     Male             9       20 to 24     332
# 103        Global       2   Female             9       20 to 24     332
# 104        Global       1     Male             9       20 to 24     332
# 105        Global       2   Female             9       20 to 24     332
# 106        Global       1     Male             9       20 to 24     332
# 107        Global       2   Female             9       20 to 24     332
# 108        Global       1     Male             9       20 to 24     332
# 109        Global       2   Female             9       20 to 24     332
# 110        Global       1     Male             9       20 to 24     332
#
#             rei_name  metric_id metric_name  year_id       val
# ...

# %%
df.iloc[100:110, 0:3] #wybierz wiersze od 100-110 i kolumny od 0-2
# Out:
#      measure_id measure_name  location_id
# 100           5   Prevalence            1
# 101           5   Prevalence            1
# 102           5   Prevalence            1
# 103           5   Prevalence            1
# 104           5   Prevalence            1
# 105           5   Prevalence            1
# 106           5   Prevalence            1
# 107           5   Prevalence            1
# 108           5   Prevalence            1
# 109           5   Prevalence            1

# %%
#przedstawi´c wyb´or wierszy z ramki danych pod warunkiem odno´snie
#okre´slonej warto´sci kolumny

df[df["sex_name"] == "Both"]
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 60               5   Prevalence            1        Global       3     Both
# 61               5   Prevalence            1        Global       3     Both
# 62               5   Prevalence            1        Global       3     Both
# 63               5   Prevalence            1        Global       3     Both
# 64               5   Prevalence            1        Global       3     Both
# ...            ...          ...          ...           ...     ...      ...
# 350545           5   Prevalence          522         Sudan       3     Both
# 350546           5   Prevalence          522         Sudan       3     Both
# 350547           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
# 350549           5   Prevalence          522         Sudan       3     Both
#
# ...

# %%
#przedstawi´c wyb´or wierszy z ramki danych pod warunkiem spelnienia
#kilku warunk´ow jednocze´snie

cardio = df[(df["sex_name"] == "Both")&(df["year_id"] == 2018) & (df["age_group_id"] <= 29)]
cardio
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 88               5   Prevalence            1        Global       3     Both
# 178              5   Prevalence            1        Global       3     Both
# 268              5   Prevalence            1        Global       3     Both
# 358              5   Prevalence            1        Global       3     Both
# 448              5   Prevalence            1        Global       3     Both
# ...            ...          ...          ...           ...     ...      ...
# 349828           5   Prevalence          522         Sudan       3     Both
# 349918           5   Prevalence          522         Sudan       3     Both
# 350008           5   Prevalence          522         Sudan       3     Both
# 350098           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
#
# ...

# %%
# wybra´c wiersze kt´ore zawieraja˛ w kolumnie kategoryzowanej okre´slone slowo

df[df["location_name"].str.contains("States")]
# Out:
#         measure_id measure_name  location_id  \
# 30780            5   Prevalence           25
# 30781            5   Prevalence           25
# 30782            5   Prevalence           25
# 30783            5   Prevalence           25
# 30784            5   Prevalence           25
# ...            ...          ...          ...
# 347125           5   Prevalence          422
# 347126           5   Prevalence          422
# 347127           5   Prevalence          422
# 347128           5   Prevalence          422
# 347129           5   Prevalence          422
#
#                            location_name  sex_id sex_name  age_group_id  \
# 30780   Micronesia (Federated States of)       1     Male             8
# 30781   Micronesia (Federated States of)       2   Female             8
# 30782   Micronesia (Federated States of)       1     Male             8
# 30783   Micronesia (Federated States of)       2   Female             8
# ...

# %%
# wybra´c wiersze kt´ore nie zawieraja˛ w kolumnie kategoryzowanej okre´slone
# slowo

df[df["location_name"].str.contains("States") == False]
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0                5   Prevalence            1        Global       1     Male
# 1                5   Prevalence            1        Global       2   Female
# 2                5   Prevalence            1        Global       1     Male
# 3                5   Prevalence            1        Global       2   Female
# 4                5   Prevalence            1        Global       1     Male
# ...            ...          ...          ...           ...     ...      ...
# 350545           5   Prevalence          522         Sudan       3     Both
# 350546           5   Prevalence          522         Sudan       3     Both
# 350547           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
# 350549           5   Prevalence          522         Sudan       3     Both
#
# ...

# %%
#utw´orz kolumne˛ na podstawie istnieja˛cyn

df["Tolerance_range"] = df["upper"] - df["lower"]
df
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0                5   Prevalence            1        Global       1     Male
# 1                5   Prevalence            1        Global       2   Female
# 2                5   Prevalence            1        Global       1     Male
# 3                5   Prevalence            1        Global       2   Female
# 4                5   Prevalence            1        Global       1     Male
# ...            ...          ...          ...           ...     ...      ...
# 350545           5   Prevalence          522         Sudan       3     Both
# 350546           5   Prevalence          522         Sudan       3     Both
# 350547           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
# 350549           5   Prevalence          522         Sudan       3     Both
#
# ...

# %%
#usu´n kolumne

df = df.drop("age_group_id", axis = 1)
df
# Out:
#         measure_id measure_name  location_id location_name  sex_id sex_name  \
# 0                5   Prevalence            1        Global       1     Male
# 1                5   Prevalence            1        Global       2   Female
# 2                5   Prevalence            1        Global       1     Male
# 3                5   Prevalence            1        Global       2   Female
# 4                5   Prevalence            1        Global       1     Male
# ...            ...          ...          ...           ...     ...      ...
# 350545           5   Prevalence          522         Sudan       3     Both
# 350546           5   Prevalence          522         Sudan       3     Both
# 350547           5   Prevalence          522         Sudan       3     Both
# 350548           5   Prevalence          522         Sudan       3     Both
# 350549           5   Prevalence          522         Sudan       3     Both
#
# ...

# %%
#zmie´n nazwe˛ kolumny

df = df.rename(columns = {"sex_name":"sex"})
df
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 0                5   Prevalence            1        Global       1    Male
# 1                5   Prevalence            1        Global       2  Female
# 2                5   Prevalence            1        Global       1    Male
# 3                5   Prevalence            1        Global       2  Female
# 4                5   Prevalence            1        Global       1    Male
# ...            ...          ...          ...           ...     ...     ...
# 350545           5   Prevalence          522         Sudan       3    Both
# 350546           5   Prevalence          522         Sudan       3    Both
# 350547           5   Prevalence          522         Sudan       3    Both
# 350548           5   Prevalence          522         Sudan       3    Both
# 350549           5   Prevalence          522         Sudan       3    Both
#
# ...

# %%
df
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 0                5   Prevalence            1        Global       1    Male
# 1                5   Prevalence            1        Global       2  Female
# 2                5   Prevalence            1        Global       1    Male
# 3                5   Prevalence            1        Global       2  Female
# 4                5   Prevalence            1        Global       1    Male
# ...            ...          ...          ...           ...     ...     ...
# 350545           5   Prevalence          522         Sudan       3    Both
# 350546           5   Prevalence          522         Sudan       3    Both
# 350547           5   Prevalence          522         Sudan       3    Both
# 350548           5   Prevalence          522         Sudan       3    Both
# 350549           5   Prevalence          522         Sudan       3    Both
#
# ...

# %%
#zachowaj ramke˛ danych jako plik csv na komputerze

df.to_csv("New_DataFrame.csv")

# %%
df
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 0                5   Prevalence            1        Global       1    Male
# 1                5   Prevalence            1        Global       2  Female
# 2                5   Prevalence            1        Global       1    Male
# 3                5   Prevalence            1        Global       2  Female
# 4                5   Prevalence            1        Global       1    Male
# ...            ...          ...          ...           ...     ...     ...
# 350545           5   Prevalence          522         Sudan       3    Both
# 350546           5   Prevalence          522         Sudan       3    Both
# 350547           5   Prevalence          522         Sudan       3    Both
# 350548           5   Prevalence          522         Sudan       3    Both
# 350549           5   Prevalence          522         Sudan       3    Both
#
# ...

# %%
#wy´swietli´c ´srednia (maksymalna˛, minimalna˛) warto´s´c z jednej kolumny

print(df["year_id"].mean())
print(df["year_id"].max())
print(df["year_id"].min())
# Out:
# 2004.5
# 2019
# 1990

# %%
#wy´swietli´c liczbe˛ wierszy

rows = len(df.axes[0])
rows
# Out:
# 350550

# %%
#wy´swietli´c warto´sci unikatowe w kolumnie

df['sex'].unique() # wartości unikatowe
# Out:
# array(['Male', 'Female', 'Both'], dtype=object)

# %%
#wy´swietli´c liczby rekord´ow odpowiadaja˛cych do warto´sci

df['sex'].value_counts() # liczba rekordów pasujących do unikalnych wartości
# Out:
# sex
# Male      116850
# Female    116850
# Both      116850
# Name: count, dtype: int64

# %%
#sortowanie wierszy ramki danych wedlug warto´sci okre´slonej kolumny
#(maleja˛co, rosna˛co)

df.sort_values(['val'], ascending = True) # sortowanie rosnąco
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 340439           5   Prevalence          396    San Marino       2  Female
# 340437           5   Prevalence          396    San Marino       2  Female
# 340429           5   Prevalence          396    San Marino       2  Female
# 340431           5   Prevalence          396    San Marino       2  Female
# 340435           5   Prevalence          396    San Marino       2  Female
# ...            ...          ...          ...           ...     ...     ...
# 8305             5   Prevalence           10      Cambodia       2  Female
# 8217             5   Prevalence           10      Cambodia       2  Female
# 8397             5   Prevalence           10      Cambodia       2  Female
# 8127             5   Prevalence           10      Cambodia       2  Female
# 8307             5   Prevalence           10      Cambodia       2  Female
#
# ...

# %%
df.sort_values(['val'], ascending =  False) # sortowanie malejąco
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 8217             5   Prevalence           10      Cambodia       2  Female
# 8397             5   Prevalence           10      Cambodia       2  Female
# 8127             5   Prevalence           10      Cambodia       2  Female
# 8307             5   Prevalence           10      Cambodia       2  Female
# 8305             5   Prevalence           10      Cambodia       2  Female
# ...            ...          ...          ...           ...     ...     ...
# 340435           5   Prevalence          396    San Marino       2  Female
# 340431           5   Prevalence          396    San Marino       2  Female
# 340429           5   Prevalence          396    San Marino       2  Female
# 340437           5   Prevalence          396    San Marino       2  Female
# 340439           5   Prevalence          396    San Marino       2  Female
#
# ...

# %%
df.sort_values(['val'], ascending =  True).head(10) # 10 Największych
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 340439           5   Prevalence          396    San Marino       2  Female
# 340437           5   Prevalence          396    San Marino       2  Female
# 340429           5   Prevalence          396    San Marino       2  Female
# 340431           5   Prevalence          396    San Marino       2  Female
# 340435           5   Prevalence          396    San Marino       2  Female
# 340433           5   Prevalence          396    San Marino       2  Female
# 340427           5   Prevalence          396    San Marino       2  Female
# 340425           5   Prevalence          396    San Marino       2  Female
# 340423           5   Prevalence          396    San Marino       2  Female
# 340421           5   Prevalence          396    San Marino       2  Female
#
#        age_group_name  rei_id         rei_name  metric_id metric_name  \
# 340439       20 to 24     332  Chewing tobacco          3        Rate
# ...

# %%
df.sort_values(['val'], ascending =  False).head(10) # 10 Najmniejszych
# Out:
#       measure_id measure_name  location_id location_name  sex_id     sex  \
# 8217           5   Prevalence           10      Cambodia       2  Female
# 8397           5   Prevalence           10      Cambodia       2  Female
# 8127           5   Prevalence           10      Cambodia       2  Female
# 8307           5   Prevalence           10      Cambodia       2  Female
# 8305           5   Prevalence           10      Cambodia       2  Female
# 8395           5   Prevalence           10      Cambodia       2  Female
# 8215           5   Prevalence           10      Cambodia       2  Female
# 8125           5   Prevalence           10      Cambodia       2  Female
# 8129           5   Prevalence           10      Cambodia       2  Female
# 8309           5   Prevalence           10      Cambodia       2  Female
#
#      age_group_name  rei_id         rei_name  metric_id metric_name  year_id  \
# 8217       85 to 89     332  Chewing tobacco          3        Rate     2003
# ...

# %%
#wy´swietli´c wierszy dla 10 najwie˛kszych warto´sci okre´slonej kolumny
#pod warunkiem okre´slonych warto´sci innej kolumny

df[(df['location_name'].isin(['Sudan','Poland','Hungary']))].nlargest(10,'val')
# Out:
#         measure_id measure_name  location_id location_name  sex_id   sex  \
# 349432           5   Prevalence          522         Sudan       1  Male
# 349438           5   Prevalence          522         Sudan       1  Male
# 349434           5   Prevalence          522         Sudan       1  Male
# 349436           5   Prevalence          522         Sudan       1  Male
# 349430           5   Prevalence          522         Sudan       1  Male
# 349428           5   Prevalence          522         Sudan       1  Male
# 349342           5   Prevalence          522         Sudan       1  Male
# 349348           5   Prevalence          522         Sudan       1  Male
# 349344           5   Prevalence          522         Sudan       1  Male
# 349346           5   Prevalence          522         Sudan       1  Male
#
#        age_group_name  rei_id         rei_name  metric_id metric_name  \
# 349432       45 to 49     332  Chewing tobacco          3        Rate
# ...

# %%
#grupowanie wierszy wedlug warto´sci kolumny kategoryzowanej, potem
#- u´srednienie warto´sci wszystkich kolumn w grupie - MultiIndex

df_new = df.groupby(['location_name','sex']).agg({'val': 'mean',
                                                    'upper': 'mean',
                                                    'lower': 'mean'})
df_new
# Out:
#                            val     upper     lower
# location_name sex
# Afghanistan   Both    0.036491  0.057880  0.021572
#               Female  0.005077  0.010820  0.002041
#               Male    0.068753  0.111568  0.039311
# Albania       Both    0.005864  0.009785  0.003375
#               Female  0.003130  0.006646  0.001277
# ...                        ...       ...       ...
# Zambia        Female  0.014409  0.030814  0.005678
#               Male    0.008172  0.015062  0.003965
# Zimbabwe      Both    0.008677  0.017079  0.003970
#               Female  0.010854  0.023365  0.004162
#               Male    0.003754  0.006850  0.001870
#
# [615 rows x 3 columns]

# %%
#grupowanie wierszy wedlug warto´sci kolumny kategoryzowanej, potem
#- u´srednienie warto´sci dla pewnych kolumn, liczba warto´sci i mediana
#dla pozostalych kolumn w grupach

df_new = df.groupby(['location_name','sex']).agg({
                        'val': 'mean',
                        'upper': ['median','count'],
                        'sex_id' : ['median','count']})
df_new
# Out:
#                            val     upper       sex_id
#                           mean    median count median count
# location_name sex
# Afghanistan   Both    0.036491  0.055316   570    3.0   570
#               Female  0.005077  0.010201   570    2.0   570
#               Male    0.068753  0.108540   570    1.0   570
# Albania       Both    0.005864  0.009446   570    3.0   570
#               Female  0.003130  0.005227   570    2.0   570
# ...                        ...       ...   ...    ...   ...
# Zambia        Female  0.014409  0.027697   570    2.0   570
#               Male    0.008172  0.011570   570    1.0   570
# Zimbabwe      Both    0.008677  0.007834   570    3.0   570
#               Female  0.010854  0.011297   570    2.0   570
#               Male    0.003754  0.006515   570    1.0   570
#
# [615 rows x 5 columns]

# %%
#wy´swietli´c nazwy kolumn indeksu zlo˙zonego

df_new.columns
# Out:
# MultiIndex([(   'val',   'mean'),
#             ( 'upper', 'median'),
#             ( 'upper',  'count'),
#             ('sex_id', 'median'),
#             ('sex_id',  'count')],
#            )

# %%
#sortowa´c kolumne˛ indeksu zlo˙zonego

df_new['upper']['median'].sort_values(ascending = True)
# Out:
# location_name  sex
# France         Both      0.002428
# Spain          Both      0.002435
# Netherlands    Both      0.002438
# Portugal       Both      0.002450
# Luxembourg     Both      0.002460
#                            ...
# India          Male      0.386419
# Bhutan         Male      0.419482
# Bangladesh     Both      0.425999
# Nepal          Male      0.503675
# Bangladesh     Female    0.546821
# Name: median, Length: 615, dtype: float64

# %%
#stworzy´c tabele˛ przystawna˛ (pivot table) na podstawie ramki danych

df_pivot = df.pivot_table(values='val', index='location_name', columns='sex', aggfunc='mean',
                      margins=False, dropna=True, fill_value=None) # tabela podsumowująca
df_pivot
# Out:
# sex                                     Both    Female      Male
# location_name
# Afghanistan                         0.036491  0.005077  0.068753
# Albania                             0.005864  0.003130  0.008647
# Algeria                             0.043335  0.006325  0.078118
# American Samoa                      0.023841  0.014986  0.032602
# Andorra                             0.001846  0.001504  0.002224
# ...                                      ...       ...       ...
# Venezuela (Bolivarian Republic of)  0.011944  0.004963  0.019783
# Viet Nam                            0.026296  0.034622  0.008547
# Yemen                               0.105273  0.075236  0.132851
# Zambia                              0.011422  0.014409  0.008172
# Zimbabwe                            0.008677  0.010854  0.003754
#
# [205 rows x 3 columns]

# %%
#wy´swietli´c indeksy i kolumny tabeli przystawnej

print(df_pivot.index)
print(df_pivot.columns)
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United States Virgin Islands', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='location_name', length=205)
# Index(['Both', 'Female', 'Male'], dtype='object', name='sex')

# %%
#utw´orz indeks zlo˙zony tabeli przystawnej i wy´swietl go

df_pivot = df.pivot_table(values='val', index=['location_name','year_id'], columns='sex', aggfunc='mean',
                      margins=False, dropna=True, fill_value=None)
df_pivot
# Out:
# sex                        Both    Female      Male
# location_name year_id
# Afghanistan   1990     0.032164  0.005649  0.062808
#               1991     0.032468  0.005646  0.062973
#               1992     0.032946  0.005642  0.063175
#               1993     0.033264  0.005640  0.063388
#               1994     0.033423  0.005639  0.063608
# ...                         ...       ...       ...
# Zimbabwe      2015     0.009535  0.012373  0.003522
#               2016     0.009718  0.012664  0.003525
#               2017     0.009902  0.012957  0.003527
#               2018     0.009887  0.012939  0.003526
#               2019     0.009874  0.012922  0.003524
#
# [6150 rows x 3 columns]

# %%
#wy´swietli´c wykres na podstawie tabeli przystawnej

df[(df['location_name'] == 'Poland') & (df['sex'] == 'Female')].pivot_table(values='val', index='year_id', columns='sex', aggfunc='mean',
                                          fill_value=None, margins=False, dropna=True).plot(kind = 'line')

plt.ylabel('People') # etykieta osi y
plt.title('Smokers over the years.') # tytuł wykresu
# Out:
# Text(0.5, 1.0, 'Smokers over the years.')

# %%
#narysowa´c histogram na podstawie warto´sci kolumny

df_bar = df[(df['sex'].isin(['Male','Female','Both']))].pivot_table(values='val', 
                index='year_id', columns='sex', aggfunc='mean',
                      fill_value=None, margins=False, dropna=True)
df_bar.plot(kind = 'bar')
plt.ylabel('Smokers')
plt.title('Mean smokers per years')
# Out:
# Text(0.5, 1.0, 'Mean smokers per years')

# %%
#przedstawi´c sposoby la˛czenia ramek danych za pomoca˛ metod merge i
#concat

df2 = pd.read_csv('IHME_GBD_2019_CHEWING_TOB_1990_2019_CIG_PC_Y2021M05D27.CSV')
df2
# Out:
#                          measure_name  location_id  \
# 0    Cigarette-Equivalents Per Capita            1
# 1    Cigarette-Equivalents Per Capita            1
# 2    Cigarette-Equivalents Per Capita            4
# 3    Cigarette-Equivalents Per Capita            4
# 4    Cigarette-Equivalents Per Capita            5
# ..                                ...          ...
# 461  Cigarette-Equivalents Per Capita          422
# 462  Cigarette-Equivalents Per Capita          435
# 463  Cigarette-Equivalents Per Capita          435
# 464  Cigarette-Equivalents Per Capita          522
# 465  Cigarette-Equivalents Per Capita          522
#
#                               location_name  sex_id sex_name  age_group_id  \
# 0                                    Global       3     Both            29
# 1                                    Global       3     Both            29
# 2    Southeast Asia, East Asia, and Oceania       3     Both            29
# ...

# %%
df
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 0                5   Prevalence            1        Global       1    Male
# 1                5   Prevalence            1        Global       2  Female
# 2                5   Prevalence            1        Global       1    Male
# 3                5   Prevalence            1        Global       2  Female
# 4                5   Prevalence            1        Global       1    Male
# ...            ...          ...          ...           ...     ...     ...
# 350545           5   Prevalence          522         Sudan       3    Both
# 350546           5   Prevalence          522         Sudan       3    Both
# 350547           5   Prevalence          522         Sudan       3    Both
# 350548           5   Prevalence          522         Sudan       3    Both
# 350549           5   Prevalence          522         Sudan       3    Both
#
# ...

# %%
df2.rename(columns = {'val': 'val_Cigarette-Equivalents Per Capita', 'upper': 'upper_Cigarette-Equivalents Per Capita', 'lower':'deaths_lower_Cigarette-Equivalents Per Capita'}, inplace = True)
df.drop('sex_id', axis = 1)
# Out:
#         measure_id measure_name  location_id location_name     sex  \
# 0                5   Prevalence            1        Global    Male
# 1                5   Prevalence            1        Global  Female
# 2                5   Prevalence            1        Global    Male
# 3                5   Prevalence            1        Global  Female
# 4                5   Prevalence            1        Global    Male
# ...            ...          ...          ...           ...     ...
# 350545           5   Prevalence          522         Sudan    Both
# 350546           5   Prevalence          522         Sudan    Both
# 350547           5   Prevalence          522         Sudan    Both
# 350548           5   Prevalence          522         Sudan    Both
# 350549           5   Prevalence          522         Sudan    Both
#
#           age_group_name  rei_id         rei_name  metric_id metric_name  \
# 0               15 to 19     332  Chewing tobacco          3        Rate
# ...

# %%
df_all = pd.merge(df, df2, on = ['location_id', 'location_name', 'age_group_name', 'year_id'], how = 'inner')

# %%
df_all
# Out:
# Empty DataFrame
# Columns: [measure_id, measure_name_x, location_id, location_name, sex_id_x, sex, age_group_name, rei_id, rei_name, metric_id, metric_name, year_id, val, upper, lower, Tolerance_range, measure_name_y, sex_id_y, sex_name, age_group_id, val_Cigarette-Equivalents Per Capita, upper_Cigarette-Equivalents Per Capita, deaths_lower_Cigarette-Equivalents Per Capita]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_all_1 = df.iloc[1:15,:]
df_all_1
# Out:
#     measure_id measure_name  location_id location_name  sex_id     sex  \
# 1            5   Prevalence            1        Global       2  Female
# 2            5   Prevalence            1        Global       1    Male
# 3            5   Prevalence            1        Global       2  Female
# 4            5   Prevalence            1        Global       1    Male
# 5            5   Prevalence            1        Global       2  Female
# 6            5   Prevalence            1        Global       1    Male
# 7            5   Prevalence            1        Global       2  Female
# 8            5   Prevalence            1        Global       1    Male
# 9            5   Prevalence            1        Global       2  Female
# 10           5   Prevalence            1        Global       1    Male
# 11           5   Prevalence            1        Global       2  Female
# 12           5   Prevalence            1        Global       1    Male
# ...

# %%
df_all_2 = df.iloc[-15::]
df_all_2
# Out:
#         measure_id measure_name  location_id location_name  sex_id   sex  \
# 350535           5   Prevalence          522         Sudan       3  Both
# 350536           5   Prevalence          522         Sudan       3  Both
# 350537           5   Prevalence          522         Sudan       3  Both
# 350538           5   Prevalence          522         Sudan       3  Both
# 350539           5   Prevalence          522         Sudan       3  Both
# 350540           5   Prevalence          522         Sudan       3  Both
# 350541           5   Prevalence          522         Sudan       3  Both
# 350542           5   Prevalence          522         Sudan       3  Both
# 350543           5   Prevalence          522         Sudan       3  Both
# 350544           5   Prevalence          522         Sudan       3  Both
# 350545           5   Prevalence          522         Sudan       3  Both
# 350546           5   Prevalence          522         Sudan       3  Both
# ...

# %%
df_all_new = pd.concat([df_all_1, df_all_2], axis = 0) # połącz ramki danych: jeśli axis = 0, to po wierszach, jeśli
# axis = 1, potem według kolumn
print(df_all_new.shape)
df_all_new
# Out:
# (29, 16)
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 1                5   Prevalence            1        Global       2  Female
# 2                5   Prevalence            1        Global       1    Male
# 3                5   Prevalence            1        Global       2  Female
# 4                5   Prevalence            1        Global       1    Male
# 5                5   Prevalence            1        Global       2  Female
# 6                5   Prevalence            1        Global       1    Male
# 7                5   Prevalence            1        Global       2  Female
# 8                5   Prevalence            1        Global       1    Male
# 9                5   Prevalence            1        Global       2  Female
# 10               5   Prevalence            1        Global       1    Male
# 11               5   Prevalence            1        Global       2  Female
# ...

# %%
#pokaza´c dodawanie nowych kolumn za pomoca˛ operacji matematy-
#cznych

df_all_new["smokers"] = df_all_new["val"] + df_all_new["upper"] + df_all_new["lower"]
df_all_new["%ValFromUpper"] = df_all_new["val"] / df_all_new["upper"]*100
df_all_new["%ValFromLower"] = df_all_new["val"] / df_all_new["lower"]*100

# %%
df_all_new
# Out:
#         measure_id measure_name  location_id location_name  sex_id     sex  \
# 1                5   Prevalence            1        Global       2  Female
# 2                5   Prevalence            1        Global       1    Male
# 3                5   Prevalence            1        Global       2  Female
# 4                5   Prevalence            1        Global       1    Male
# 5                5   Prevalence            1        Global       2  Female
# 6                5   Prevalence            1        Global       1    Male
# 7                5   Prevalence            1        Global       2  Female
# 8                5   Prevalence            1        Global       1    Male
# 9                5   Prevalence            1        Global       2  Female
# 10               5   Prevalence            1        Global       1    Male
# 11               5   Prevalence            1        Global       2  Female
# ...

# %%
#przedstawi´c na przykladzie dodawanie nowych kolumn z pomoca˛ funkcji
#lambda
year_id = [2017,2018,2019]
df_all_new = df_all_new.reset_index()
df_all_new['Is2017-2019'] = df_all['year_id'].apply(lambda x: True if x in year_id else False )
df_all_new
# Out:
#      index  measure_id measure_name  location_id location_name  sex_id  \
# 0        1           5   Prevalence            1        Global       2
# 1        2           5   Prevalence            1        Global       1
# 2        3           5   Prevalence            1        Global       2
# 3        4           5   Prevalence            1        Global       1
# 4        5           5   Prevalence            1        Global       2
# 5        6           5   Prevalence            1        Global       1
# 6        7           5   Prevalence            1        Global       2
# 7        8           5   Prevalence            1        Global       1
# 8        9           5   Prevalence            1        Global       2
# 9       10           5   Prevalence            1        Global       1
# 10      11           5   Prevalence            1        Global       2
# 11      12           5   Prevalence            1        Global       1
# ...

# %%
#przedstawi´c mo˙zliwo´sci pracy z du˙zymi plikami przy u˙zyciu argumentu
#chunksize

for chunk_df in pd.read_csv('IHME_GBD_2019_CHEWING_TOB_1990_2019_CIG_PC_Y2021M05D27.CSV', 
                      chunksize = 50000):
    print("CHUNK DF")
    print(chunk_df.head())
# Out:
# CHUNK DF
#                        measure_name  location_id  \
# 0  Cigarette-Equivalents Per Capita            1
# 1  Cigarette-Equivalents Per Capita            1
# 2  Cigarette-Equivalents Per Capita            4
# 3  Cigarette-Equivalents Per Capita            4
# 4  Cigarette-Equivalents Per Capita            5
#
#                             location_name  sex_id sex_name  age_group_id  \
# 0                                  Global       3     Both            29
# 1                                  Global       3     Both            29
# 2  Southeast Asia, East Asia, and Oceania       3     Both            29
# 3  Southeast Asia, East Asia, and Oceania       3     Both            29
# 4                               East Asia       3     Both            29
#
#   age_group_name  year_id          val        upper        lower
# 0      15+ years     1990  1484.256502  1531.563739  1436.151878
# 1      15+ years     2019  1113.754663  1161.263946  1069.765828
# ...

# %%
new_df = pd.DataFrame() # pusta ramka danych
for chunk_df in pd.read_csv('IHME_GBD_2019_CHEWING_TOB_1990_2019_CIG_PC_Y2021M05D27.CSV', 
                      chunksize = 50000):
    result = chunk_df.groupby(['location_name', 'year_id']).agg({'val': 'mean',
                                                    'upper': 'max'})
    new_df = pd.concat([new_df,result])
    
new_df
# Out:
#                                val        upper
# location_name year_id
# Afghanistan   1990      274.126957   320.558021
#               2019      444.334632   546.171500
# Albania       1990     1894.040861  2224.731864
#               2019     1941.384044  2305.846372
# Algeria       1990     1259.079364  1381.657971
# ...                            ...          ...
# Yemen         2019     1391.887788  1712.648491
# Zambia        1990      308.165288   343.536927
#               2019      296.250416   366.554416
# Zimbabwe      1990      931.803728  1130.361142
#               2019      898.367226  1132.376771
#
# [462 rows x 2 columns]
